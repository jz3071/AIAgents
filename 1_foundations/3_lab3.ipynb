# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("/Users/jiaozhou/Proj/agents/1_foundations/jiao_linkedIn.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

reader = PdfReader("/Users/jiaozhou/Proj/agents/1_foundations/jiao_resume.pdf")
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text
# Out:
# Ignoring wrong pointing object 6 0 (offset 0)
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 10 0 (offset 0)
# Ignoring wrong pointing object 12 0 (offset 0)
# Ignoring wrong pointing object 14 0 (offset 0)
# Ignoring wrong pointing object 16 0 (offset 0)
# Ignoring wrong pointing object 18 0 (offset 0)
# Ignoring wrong pointing object 20 0 (offset 0)
# Ignoring wrong pointing object 22 0 (offset 0)
# Ignoring wrong pointing object 24 0 (offset 0)
# Ignoring wrong pointing object 26 0 (offset 0)
# Ignoring wrong pointing object 29 0 (offset 0)
# Ignoring wrong pointing object 31 0 (offset 0)

# %%
print(linkedin)
# Out:
# 500+ connections
# Addprofilesection Enhance profile
# Senior Software Engineer at Google
# New York, New York, United States·Contact info
# Jiao (Miranda) Zhou
# Google
# Columbia Engineering
# Opento Resources
# Tell non-profitsyou're interested in getting involved with your time andskillsGet started
# Suggested for you
# Private to you
# Are you still working at Google?
# Keeping your profile up-to-date helps you attractthe right opportunities.
# Confirm current position
# Highlight you
# Make it easier for recruitwhere and how you used
# Edit experience
# AnalyticsPrivate to you
# 497 profile viewsDiscover who's viewed your profile.
# 1 post impressionCheck out who's engaging with your posts.Past 7 days
# 178 search appearancesSee how often you appear in search results.
# Home My Network Jobs MessagingNotifications Me
#  For Business Retry for $
# 10 3 20
# Update to our terms
# Weʼre updating our terms on November 3, 2025. See whatʼs new and how to manage your data. Learn more
# 10/3/25, 3:17 PM (33) Jiao Zhou | LinkedIn
# https://www.linkedin.com/in/jiaozhou/ 1/6Show all analytics
# About
# Passionate Software Developer
# Activity1,588 followers
# Create a post
# You havenʼt posted yetPosts you share will be displayed here.
# Show all activity
# Experience
# Show all 12 experiences
# GoogleFull-time · 3 yrs 5 mosNew York City Metropolitan Area
# L4 Software EngineerJun 2022 - Oct 2024 · 2 yrs 5 mos
# L5 Software EngineerOct 2024 - Present · 1 yr 1 mo
# Junior DeveloperAkuna Capital · Full-timeFeb 2020 - Jun 2022 · 2 yrs 5 mosGreater Chicago Area
# MenteeMarshall Career Advantage Program (CAP)Aug 2016 - May 2018 · 1 yr 10 mosLos Angeles Metropolitan Area
# Middle School Volunteer EducatorBerendo Middle SchoolFeb 2018 - Apr 2018 · 3 mosLos Angeles, California
# • Taught weekly biology classes to 15 Berendo Middle School seventh-graders
# Wealth Management InternUBSMay 2017 - Aug 2017 · 4 mosLos Angeles, California
# • Identified credit risks and relative values across US credit sector,including investment grade, high yield, and credit derivatives by……see more
# Education
# Update to our terms
# Weʼre updating our terms on November 3, 2025. See whatʼs new and how to manage your data. Learn more
# 10/3/25, 3:17 PM (33) Jiao Zhou | LinkedIn
# https://www.linkedin.com/in/jiaozhou/ 2/6Show all 4 educations
# Columbia EngineeringMaster's degree, Computer Science2018 - 2019
# Grade: GPA 3.64
# Machine Learning Track
# New York UniversityExtended Bridge to Computer Science, Computer Science2018 - 2018
# The bridge program is a six-months intensive study of the requiredtopics which are requisite information for general admission into the NY…
# Volunteering
# Show all 3 volunteer experiences
# VolunteerThe River Food PantryOct 2015 - Feb 2016 · 5 mosPoverty Alleviation
# • Provided hot meals, groceries, clothing, and other household items toDane County families that are struggling to meet their basic needs
# VolunteerLakeshore Nature PreserveMay 2015 - Present · 10 yrs 6 mosEnvironment
# • Volunteered to maintain the nature reserve area near lake Mendota
# Skills
# Show all 30 skills
# Teamwork
# 15 endorsements
# Microsoft Excel
# 15 endorsements
# Endorsed byJason Gongwho is highly skilled at this
# Courses
# Show all 43 courses
# Advanced Business Writing340
# Associated with University of Southern California
# American Government and PoliticsPolitic Science 104
# Associated with University of Wisconsin-Madison
# Honors & awards
# Update to our terms
# Weʼre updating our terms on November 3, 2025. See whatʼs new and how to manage your data. Learn more
# 10/3/25, 3:17 PM (33) Jiao Zhou | LinkedIn
# https://www.linkedin.com/in/jiaozhou/ 3/6Passed CFA Level 1Issued by CFA Institute · Jun 2018
# My score is above 90 percentile
# Winning $2000 sponsorship from EY for National Association ofBlack AccountantsIssued by EY · Apr 2016
# Associated with National Association of Black Accountants (NABA)
# I represented NABA with other board members at Beta Alpha Psi auction eventand secured a $2000 grant for NABA from EY, which is the first grant in the…
# Languages
# ChineseNative or bilingual proficiency
# EnglishFull professional proficiency
# Organizations
# Institute of Management Accountants (IMA)Social Director · Sep 2015 - Dec 2015
# Associated with University of Wisconsin-Madison
# Organized barbeques, club meetings, and social gatherings, and achieved anaverage attendance of forty people
# Chinese Students and Scholars Association (CSSA)- MadisonTreasurer · Feb 2015 - May 2015
# Associated with University of Wisconsin-Madison
# Recorded transactions and reported on current financial events for weeklydiscussions with fellow members… …see more
# Interests
# Show all Top Voices
# Top Voices Companies Groups Schools
# Bill Gates· 3rdChair, Gates Foundation and Founder, Breakthrough Energy38,888,434 followers
# Following
# Kevin O'Leary· 3rdChairman, OʼLeary Ventures and Beanstox4,476,637 followers
# Following
# Profile language
# Public profile & URL
# Update to our terms
# Weʼre updating our terms on November 3, 2025. See whatʼs new and how to manage your data. Learn more
# 10/3/25, 3:17 PM (33) Jiao Zhou | LinkedIn
# https://www.linkedin.com/in/jiaozhou/ 4/6www.linkedin.com/in/jiaozhou
# Jiao, explore relevant opportunitieswith Epic
# Get the latest jobs and industry news
# Follow
# Promoted
# Who your viewers also viewedPrivate to you
# Someone at The Juilliard School
# View
# Software Developer at Google
# View
# Software Developer in the Software…
# View
# Software Developer at Google
# View
# People you may knowFrom your school
# Show all
# Mengqi Wang
# Connect
# Software Engineer at Google
# yibo zhu
# Connect
# Software Engineer at Google
# Jiayan Hu
# Connect
# SWE @ DRW
# Shiyuan Zhang
# Connect
# Software Engineer at Google
# Albert Yang
# Connect
# MLE @ Google | Post-training LLMs
# Update to our terms
# Weʼre updating our terms on November 3, 2025. See whatʼs new and how to manage your data. Learn more
# 10/3/25, 3:17 PM (33) Jiao Zhou | LinkedIn
# https://www.linkedin.com/in/jiaozhou/ 5/6About Accessibility Talent Solutions
# Professional CommunityPolicies Careers Marketing Solutions
# Ad Choices Advertising
# Sales Solutions Mobile Small Business
# Safety Center
# Questions?Visit our Help Center.
# Manage your account and privacyGo to your Settings.
# Recommendation transparencyLearn more about Recommended Content.
# Select Language
# LinkedIn Corporation © 2025
# You might likePages for you
# Show all
# OpenAI
# 8,693,065 followers
# 1 connection works here
# Follow
# Research Services
# Google Cloud
# 2,968,942 followers
# 139 connections follow this page
# Follow
# Software Development
# Privacy & Terms
# English (English)
# Update to our terms
# Weʼre updating our terms on November 3, 2025. See whatʼs new and how to manage your data. Learn more
# 10/3/25, 3:17 PM (33) Jiao Zhou | LinkedIn
# https://www.linkedin.com/in/jiaozhou/ 6/6Jiao (Miranda) Zhou   Email: jz3071@columbia.edu  Address: 29-59 Northern Boulevard, Unit 40R, Long Island City, NY 11101                Tel: (323) 420-7261    WORK EXPERIENCE  Google   New York, NY  L5(Senior) Software Engineer at ChromeOS team Nov 2024 – Present  • Lead the project to bring Android VPN Apps to ChromeOS Flex.  New York, NY  L4 Software Engineer at ChromeOS team July 2022 – Nov 2024  • Lead Chrome OS Flex Kernel components. • Maintain the stability of ChromeOS by fixing any software and hardware issues in a timely manner.  Akuna Capital   Chicago, IL  Risk Developer  Oct 2020 – July 2022  • Developed a risk matrix tool which provides an estimate of our P&L and greeks for options portfolios as the underlying products moves. It uses our current vol parameters / skew dynamics and uses assumptions about the relative moves of the underlying products in the portfolio to predict risk matrixes. • Created a new quantitative risk model which compared Akuna Vol Curve with Market Neutral Vol Carve and calculated marked out P&L for each desk. • Developed parsers to extract raw data from ABN, SPAN, and ORC in the pdf format, then processed data and generated summarized haircut reports for analysts to view.  • Maintain risk tools which help traders to run different analytic scripts on demand.  Compliance Developer  Feb 2020 – Oct 2020  • Developed tools to monitor and maintain obligations with exchanges that Akuna trades with using Python, SQL, Pub Sub. • Managed interfacing with 20 exchanges each communicating with a different binary protocol and generating terabytes of data daily. • Created dashboards using React, Redux to visualize surveillance data for user friendly consumption. • Lead the project to migrate all Akuna python packages from python 3.6 to python 3.8.   EDUCATION
#  SKILLS  Languages  Python, C++, JavaScript, CSS, Bash  Technologies  React+Redux, Docker, Redis, Git, MySQL, PyTorch, TensorFlow AWS  EC2, ECS, SQS, SNS, Lambda, S3, Dynamo DB, Cloud Watch, API Gateway Certifications CFA Level 1 (90th percentile)
# Columbia University- New York, NY 2018-2020  Master of Science, Computer Science, Machine Learning Track GPA:  3.64/4.00   University of Southern California- Los Angeles, CA 2016-2018  Bachelor of Science, Business Administration, Accounting and Finance GPA:  3.8/4.00

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Jiao Zhou"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Jiao Zhou. You are answering questions on Jiao Zhou's website, particularly questions related to Jiao Zhou's career, background, skills and experience. Your responsibility is to represent Jiao Zhou for interactions on the website as faithfully as possible. You are given a summary of Jiao Zhou's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nMy name is Ed Donner. I'm an entrepreneur, software engineer and data scientist. I'm originally from London, England, but I moved to NYC in 2000.\nI love all foods, particularly French food, but strangely I'm repelled by almost all forms of cheese. I'm not allergic, I just hate the taste! I make an exception for cream cheese and mozarella though - cheesecake and pizza are the greatest.\n\n## LinkedIn Profile:\n500+ connections\nAddprofilesection Enhance profile\nSenior Software Engineer at Google\nNew York, New York, United States·Contact info\nJiao (Miranda) Zhou\nGoogle\nColumbia Engineering\nOpento Resources\nTell non-profitsyou're interested in getting involved with your time andskillsGet started\nSuggested for you\nPrivate to you\nAre you still working at Google?\nKeeping your profile up-to-date helps you attractthe right opportunities.\nConfirm current position\nHighlight you\nMake it easier for recruitwhere and how you used\nEdit experience\nAnalyticsPrivate to you\n497 profile viewsDiscover who's viewed your profile.\n1 post impressionCheck out who's engaging with your posts.Past 7 days\n178 search appearancesSee how often you appear in search results.\nHome My Network Jobs MessagingNotifications Me\n For Business Retry for $\n10 3 20\nUpdate to our terms\nWeʼre updating our terms on November 3, 2025. See whatʼs new and how to manage your data. Learn more\n10/3/25, 3:17 PM (33) Jiao Zhou | LinkedIn\nhttps://www.linkedin.com/in/jiaozhou/ 1/6Show all analytics\nAbout\nPassionate Software Developer\nActivity1,588 followers\nCreate a post\nYou havenʼt posted yetPosts you share will be displayed here.\nShow all activity\nExperience\nShow all 12 experiences\nGoogleFull-time · 3 yrs 5 mosNew York City Metropolitan Area\nL4 Software EngineerJun 2022 - Oct 2024 · 2 yrs 5 mos\nL5 Software EngineerOct 2024 - Present · 1 yr 1 mo\nJunior DeveloperAkuna Capital · Full-timeFeb 2020 - Jun 2022 · 2 yrs 5 mosGreater Chicago Area\nMenteeMarshall Career Advantage Program (CAP)Aug 2016 - May 2018 · 1 yr 10 mosLos Angeles Metropolitan Area\nMiddle School Volunteer EducatorBerendo Middle SchoolFeb 2018 - Apr 2018 · 3 mosLos Angeles, California\n• Taught weekly biology classes to 15 Berendo Middle School seventh-graders\nWealth Management InternUBSMay 2017 - Aug 2017 · 4 mosLos Angeles, California\n• Identified credit risks and relative values across US credit sector,including investment grade, high yield, and credit derivatives by……see more\nEducation\nUpdate to our terms\nWeʼre updating our terms on November 3, 2025. See whatʼs new and how to manage your data. Learn more\n10/3/25, 3:17 PM (33) Jiao Zhou | LinkedIn\nhttps://www.linkedin.com/in/jiaozhou/ 2/6Show all 4 educations\nColumbia EngineeringMaster's degree, Computer Science2018 - 2019\nGrade: GPA 3.64\nMachine Learning Track\nNew York UniversityExtended Bridge to Computer Science, Computer Science2018 - 2018\nThe bridge program is a six-months intensive study of the requiredtopics which are requisite information for general admission into the NY…\nVolunteering\nShow all 3 volunteer experiences\nVolunteerThe River Food PantryOct 2015 - Feb 2016 · 5 mosPoverty Alleviation\n• Provided hot meals, groceries, clothing, and other household items toDane County families that are struggling to meet their basic needs\nVolunteerLakeshore Nature PreserveMay 2015 - Present · 10 yrs 6 mosEnvironment\n• Volunteered to maintain the nature reserve area near  ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
api_key = os.getenv("GOOGLE_API_KEY")
print(api_key)
# Out:
# [REDACTED]

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.0-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# "Currently, I do not hold a patent. My primary focus has been on software engineering and development, particularly in areas like risk modeling and systems integration during my time at Google and Akuna Capital. If you have any specific inquiries about my work or projects, I'd be happy to discuss them!"

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback='The response is appropriate, professional and a good answer to the question asked. It would be good to know whether Jiao has applied for any patents or been involved in work that would generate a patent, however the response is still acceptable since it directly answers the question.')

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    while not evaluation.is_acceptable:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7864
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7864/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
